# %%
# 임시 테스트 파일
from src.config import Config

# Config 객체 생성 테스트
config = Config()
print(f"output_unmask_type: {config.output_unmask_type}")
print(f"text_masker_config: {config.text_masker_config}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torch
#       3 if torch.cuda.is_available():
#       4     print(f"PyTorch CUDA version: {torch.version.cuda}")
#
# File c:\Users\junto\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:1798
#    1795 from torch._tensor import Tensor  # usort: skip
#    1797 # needs to be after torch.Tensor is defined to avoid circular dependencies
# -> 1798 from torch import storage as storage  # usort: skip
#    1799 from torch.storage import (
#    1800     _LegacyStorage,
#    1801     _StorageBase,
#    (...)
#    1804     UntypedStorage,
#    1805 )
#    1808 # NOTE: New <type>Storage classes should never be added. When adding a new
#    1809 # dtype, use torch.storage.TypedStorage directly.
#
# ...
