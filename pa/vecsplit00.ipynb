# %%
# Cell 1: Imports & Environment Setup
# %pip install regex pandas numpy tqdm openpyxl soynlp
# %pip install torch>=2.6.0 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# %pip install sentence-transformers FlagEmbedding
import os
import sys
import logging
import torch
import openpyxl
import regex as re
import numpy as np
import pandas as pd
from typing import List, Tuple, Dict, Any, Optional, Callable
from tqdm.notebook import tqdm
from FlagEmbedding import BGEM3FlagModel
from transformers import AutoTokenizer, AutoModel

# 파일 경로 설정
input_path = "C:/Users/junto/Downloads/head-repo/SP/split_p/input_p.xlsx"
output_path = "C:/Users/junto/Downloads/head-repo/SP/split_p/output_p.xlsx"

# (Optional) 환경 점검
print("NumPy", np.__version__)
print("Pandas", pd.__version__)
# Out:
# Requirement already satisfied: regex in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (2024.11.6)
# Requirement already satisfied: pandas in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (2.2.6)
# Requirement already satisfied: tqdm in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (4.67.1)
# Requirement already satisfied: openpyxl in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (3.1.5)
# Requirement already satisfied: soynlp in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (0.0.493)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: colorama in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: et-xmlfile in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: psutil>=5.0.1 in c:\users\junto\appdata\roaming\python\python310\site-packages (from soynlp) (7.0.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from soynlp) (1.15.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from soynlp) (1.7.0)
# Requirement already satisfied: six>=1.5 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.20.0->soynlp) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.20.0->soynlp) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: sentence-transformers in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (4.1.0)
# Requirement already satisfied: FlagEmbedding in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (1.3.5)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (4.52.4)
# Requirement already satisfied: tqdm in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.7.0)
# Requirement already satisfied: scipy in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (0.33.0)
# Requirement already satisfied: Pillow in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (4.14.0)
# Requirement already satisfied: filelock in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: datasets>=2.19.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from FlagEmbedding) (3.6.0)
# Requirement already satisfied: accelerate>=0.20.1 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from FlagEmbedding) (1.7.0)
# Requirement already satisfied: peft in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from FlagEmbedding) (0.15.2)
# Requirement already satisfied: ir-datasets in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from FlagEmbedding) (0.5.10)
# Requirement already satisfied: sentencepiece in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from FlagEmbedding) (0.2.0)
# Requirement already satisfied: protobuf in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from FlagEmbedding) (6.31.1)
# Requirement already satisfied: psutil in c:\users\junto\appdata\roaming\python\python310\site-packages (from accelerate>=0.20.1->FlagEmbedding) (7.0.0)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from datasets>=2.19.0->FlagEmbedding) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from datasets>=2.19.0->FlagEmbedding) (0.3.8)
# Requirement already satisfied: pandas in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from datasets>=2.19.0->FlagEmbedding) (2.3.0)
# Requirement already satisfied: xxhash in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from datasets>=2.19.0->FlagEmbedding) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from datasets>=2.19.0->FlagEmbedding) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding) (3.12.12)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding) (1.20.1)
# Requirement already satisfied: idna>=2.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.4.26)
# Requirement already satisfied: networkx in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from ir-datasets->FlagEmbedding) (4.13.4)
# Requirement already satisfied: inscriptis>=2.2.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from ir-datasets->FlagEmbedding) (2.6.0)
# Requirement already satisfied: lxml>=4.5.2 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from ir-datasets->FlagEmbedding) (5.4.0)
# Requirement already satisfied: trec-car-tools>=2.5.4 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from ir-datasets->FlagEmbedding) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from ir-datasets->FlagEmbedding) (4.4.4)
# Requirement already satisfied: warc3-wet>=0.2.3 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from ir-datasets->FlagEmbedding) (0.2.5)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from ir-datasets->FlagEmbedding) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from ir-datasets->FlagEmbedding) (0.1.9)
# Requirement already satisfied: ijson>=3.1.3 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from ir-datasets->FlagEmbedding) (3.4.0)
# Requirement already satisfied: unlzw3>=0.2.1 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from ir-datasets->FlagEmbedding) (0.2.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4>=4.4.1->ir-datasets->FlagEmbedding) (2.7)
# Requirement already satisfied: cbor>=1.0.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from trec-car-tools>=2.5.4->ir-datasets->FlagEmbedding) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from pandas->datasets>=2.19.0->FlagEmbedding) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from pandas->datasets>=2.19.0->FlagEmbedding) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from pandas->datasets>=2.19.0->FlagEmbedding) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.19.0->FlagEmbedding) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\junto\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# NumPy 2.2.6
# Pandas 2.3.0

# %%
# Cell 2: Tokenizer Initialization
tokenizer = BertTokenizerFast.from_pretrained('bert-base-multilingual-cased')

def tokenize(text, method='bert'):
    if method == 'bert':
        return bert_tokenizer.tokenize(text)
    elif method == 'spm':
        return sp.encode(text, out_type=str)
    else:
        raise ValueError(f"Unknown tokenization method: {method}")
    
# Cell 3: Load Source & Target Texts from Excel
# input_p.xlsx에 'src' 및 'tgt' 컬럼이 있다고 가정
df_input = pd.read_excel(input_path)
src_full = df_input['원문'].astype(str).str.cat(sep=' ')
tgt_full = df_input['번역문'].astype(str).str.cat(sep=' ')

# %%
# Cell 4: Sentence Splitting (기존 기준 유지)
def split_sentences(text):
    sents = re.split(r'(?<=[。？！.!?])\s+', text)
    parts = []
    for s in sents:
        if len(s) > 150:
            parts.extend([s[i:i+150] for i in range(0, len(s), 150)])
        else:
            parts.append(s)
    merged, buffer = [], ''
    for seg in parts:
        han_count = len(re.findall(r'[\u4E00-\u9FFF]', seg))
        if han_count <= 3:
            buffer += seg
        else:
            if buffer:
                if merged:
                    merged[-1] += buffer
                buffer = ''
            merged.append(seg)
    if buffer and merged:
        merged[-1] += buffer
    return [m.strip() for m in merged]

# %%
# Cell 5: Generate Target Units (Tokenized)
tgt_sents = split_sentences(tgt_full)
tgt_units = [' '.join(tokenize(s, method='bert')) for s in tgt_sents]

# Cell 6: Initial Source Chunking
def chunk_src(src_text, max_chars=200):
    sents = split_sentences(src_text)
    chunks, buf = [], ''
    for s in sents:
        if len(buf) + len(s) > max_chars:
            chunks.append(buf.strip())
            buf = s
        else:
            buf += s
    if buf:
        chunks.append(buf.strip())
    return chunks

src_chunks = chunk_src(src_full)

# %%
# OpenAI Embeddings API 사용
import openai
import numpy as np
from typing import List
import time
from openai import OpenAI

# OpenAI API 키 설정 (필요한 경우)
client = OpenAI(api_key='your-api-key')

def get_openai_embeddings(texts: List[str], model="text-embedding-3-small"):
    """OpenAI API를 사용한 임베딩"""
    embeddings = []
    
    for i, text in enumerate(texts):
        try:
            response = openai.embeddings.create(
                input=text,
                model=model
            )
            embeddings.append(response.data[0].embedding)
            
            if i % 10 == 0:
                print(f"Processed {i}/{len(texts)} texts")
                time.sleep(0.1)  # API 제한 방지
                
        except Exception as e:
            print(f"Error with text {i}: {e}")
            # 기본값으로 0 벡터 사용
            embeddings.append([0.0] * 1536)  # text-embedding-3-small 차원
    
    return np.array(embeddings)

# 사용 예시 (API 키가 있는 경우)
# src_embs = get_openai_embeddings(src_chunks)
# tgt_embs = get_openai_embeddings(tgt_units)

# %%
# Cell 9: Split & Collate Results from assignments (OpenAI Embedding 기반)
records = []
for tgt_i, src_j in assignments:
    records.append({
        'tgt_id': tgt_i,
        'tgt_text': tgt_sents[tgt_i],
        'src_chunk_id': src_j,
        'src_text': src_chunks[src_j]
    })

df_output = pd.DataFrame(records)
df_output.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Cell 9: Split & Collate Results from assignments (OpenAI Embedding 기반)
#       2 records = []
# ----> 3 for tgt_i, src_j in assignments:
#       4     records.append({
#       5         'tgt_id': tgt_i,
#       6         'tgt_text': tgt_sents[tgt_i],
#       7         'src_chunk_id': src_j,
#       8         'src_text': src_chunks[src_j]
#       9     })
#      11 df_output = pd.DataFrame(records)
#
# NameError: name 'assignments' is not defined

# %%
# Cell 10: Save Output to Excel
df_output.to_excel(output_path, index=False)
print(f"Output saved to {output_path}")
